# %% [markdown]
# ## Worldwide Earthquake Events API - Bronze Layer Processing

# %%
from datetime import datetime

# Start time
start_time = datetime.now()
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 3, Finished, Available, Finished, False)

# %%
import requests
import json
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 4, Finished, Available, Finished, False)

# %%
"""
Sample Date Logic for Understanding API URL Construction

(Keep this snippet commented when running the pipeline)
"""

# from datetime import date, timedelta

# start_date = date.today() - timedelta(7) 
# end_date = date.today() - timedelta(1) 

# url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

# print(url)
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 5, Finished, Available, Finished, False)
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2026-03-18&endtime=2026-03-24

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 6, Finished, Available, Finished, False)

# %%
# Make the GET request to fetch data
response = requests.get(url)
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 7, Finished, Available, Finished, False)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Get the JSON response
    data = response.json()
    data = data['features']
    
    # Specify the file name (and path if needed)
    file_path = f'/lakehouse/default/Files/{start_date}_earthquake_data.json'
    
    # Open the file in write mode ('w') and save the JSON data
    with open(file_path, 'w') as file:
        # The `json.dump` method serializes `data` as a JSON formatted stream to `file`
        # `indent=4` makes the file human-readable by adding whitespace
        json.dump(data, file, indent=4)
        
    print(f"Data successfully saved to {file_path}")
else:
    print("Failed to fetch data. Status code:", response.status_code)
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 8, Finished, Available, Finished, False)
# Data successfully saved to /lakehouse/default/Files/2026-03-18_earthquake_data.json

# %%
"""
Sample Code: Reading the 2026-03-18_earthquake_data.json file into Spark for reference

(Keep this snippet commented when running the pipeline)
"""

# df = spark.read.option("multiline", "true").json("Files/2026-03-18_earthquake_data.json")
# # df now is a Spark DataFrame containing JSON data from "Files/2026-03-18_earthquake_data.json".
# display(df)
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 9, Finished, Available, Finished, False)
# '\nSample Code: Reading the 2026-03-18_earthquake_data.json file into Spark for reference\n\n(Keep this snippet commented when running the pipeline)\n'

# %%
end_time = datetime.now()

# Runtime difference
runtime = end_time - start_time

print("Runtime    :", runtime)
# Out:
# StatementMeta(, fc78181a-5b17-40e0-b8e9-0fcf0c0b381f, 10, Finished, Available, Finished, False)
# Runtime    : 0:00:05.948399
