# %% [markdown]
# ## Worldwide Earthquake Events API - Silver Layer Processing

# %%
from datetime import datetime

# Start time
start_time = datetime.now()
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 3, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 4, Finished, Available, Finished, False)

# %%
"""
Reference Snippet: Loading the earthquake JSON file based on a sample start_date

(Keep this snippet commented when running the pipeline)
"""

# from datetime import date, timedelta

# start_date = date.today() - timedelta(7)
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 5, Finished, Available, Finished, False)

# %%
# df is a Spark DataFrame containing JSON data
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 6, Finished, Available, Finished, False)

# %%
# Reshape earthquake data by extracting and renaming key attributes for further analysis.
df = \
df.\
    select(
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
        )
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 7, Finished, Available, Finished, False)

# %%
# Convert 'time' and 'updated' columns from milliseconds to timestamp format for clearer datetime representation.
df = df.\
    withColumn('time', col('time')/1000).\
    withColumn('updated', col('updated')/1000).\
    withColumn('time', col('time').cast(TimestampType())).\
    withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 8, Finished, Available, Finished, False)

# %%
# appending the data to the silver table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 9, Finished, Available, Finished, False)

# %%
end_time = datetime.now()

# Runtime difference
runtime = end_time - start_time

print("Runtime    :", runtime)
# Out:
# StatementMeta(, 9481170b-011a-45a7-990f-bdec50678de8, 10, Finished, Available, Finished, False)
# Runtime    : 0:00:17.620264
